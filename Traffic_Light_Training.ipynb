# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 63.5 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
YOLO('yolov8n.pt')
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C2f(
#         (cv1): Conv(
# ...

# %%
# !unzip Traffic-Light-Detection.v2i.yolov8.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: train/labels/001672_jpg.rf.723eb57be1f9ab59110645a9e1eebae0.txt
#  extracting: train/labels/001673_jpg.rf.49720e8903c7bed0ad4484e58167b192.txt
#  extracting: train/labels/001675_jpg.rf.ae33c16d330fb53516394f866656821f.txt
#  extracting: train/labels/001676_jpg.rf.31d22bbc5bb0ff48fb43c16172b8e3c5.txt
#  extracting: train/labels/001676_jpg.rf.97faa4cddbf0b046ec0735ad81a99f14.txt
#  extracting: train/labels/001677_jpg.rf.adeeeb581ff6b6971ebdb55fe96c40a6.txt
#  extracting: train/labels/001678_jpg.rf.99459b82db65181a9d2638610e3fd571.txt
#  extracting: train/labels/001679_jpg.rf.6cc5f6b184d931042b7aabcbef6a3cc8.txt
#  extracting: train/labels/001679_jpg.rf.791ed3d2575bf68f50cdc0fb031911ae.txt
#  extracting: train/labels/001680_jpg.rf.27ab05effc4592b3f4d274cf4fc95f46.txt
#  extracting: train/labels/001680_jpg.rf.e0717cb3c1373349ff090398e94a183f.txt
# ...

# %%
# !cat /content/data.yaml
# Out:
# train: ../train/images
# val: ../valid/images
# test: ../test/images
#
# nc: 4
# names: ['green', 'off', 'red', 'yellow']
#
# roboflow:
#   workspace: yolo-babua
#   project: traffic-light-detection-h8cvg
#   version: 2
#   license: CC BY 4.0
#   url: https://universe.roboflow.com/yolo-babua/traffic-light-detection-h8cvg/dataset/2

# %%
# !yolo detect train \
model=yolov8n.pt \
data=/content/data.yaml \
epochs=50 \
imgsz=640 \
batch=16
# Out:
# Ultralytics 8.4.9 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
